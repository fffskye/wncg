# %%
import random
list=[]
for x in range(65,91):
    a=str(chr(x)) 
    list.append( a )
for x in range(97,123):
    a=str(chr(x))  
    list.append(a)     
for x in range(1,10):
    list.append(str(x))
def a():
    s=' '
    for x in range(16):
        a=random.choice(list)
        s=s+a
    print(s)
for x in range(1,200):
    a()
# Out:
#  XJUsngxRQbI4adBG
#  MKJYsrR6qzJGFQIq
#  8CbGTxza4Myv1Jvo
#  tLMFyZaynm7L5SBO
#  ZUgAO2kNkKj5zjHB
#  JzDdw7tTdr9Aqmcw
#  6sdZbY7cOqjsyJ1s
#  2VbZZY9j6xkTc8Qw
#  gfggFyL1TT6M319R
#  RQUBh3PydKkGV6xC
#  tC7E7PYE5JKhbZlL
#  mQqzoOzHdU6ANCDq
#  MulE4HBl6zlF2OrY
#  R6griDbxIwV9tUgK
#  BUM1vNUcPp6xFOKp
#  XYLRPHGYpdzwKYI7
#  lfZqyxWm2MfH8qfa
#  r5toInmZdejJxKKd
#  WR69MCeolyrPOw56
#  lDLnxpDyLogY1mMY
#  AQ7OSLf2QHrTZPBc
#  gzXSC7ttPyZ9XmRT
#  Qv2h9YrxFqGK1KFl
#  yYAp5baN3TzJAvCr
#  fYF9MmdizdqXnFn7
#  yZm8oF2kFxUJ11sV
#  7uFAMu7sRj44rg3b
#  qTM5oxqyVcCs3Usp
#  6JYcLBFLRmEjaZnP
#  EmmVhUvKfWinKwGl
#  kCkBHwTrOBbhHKbf
#  n4inf1cgkjESDIAO
#  GqITQr9FRM6Ko9u3
#  xTfj9krPkzhMUsFZ
#  1TevM7zJ7fXHjnky
#  CdQBLs8peIjMoVpF
#  hZRWC1x8OjUjzPCS
#  Epe3O3WDTQvMlMHE
#  zapVE5ifRqDupx4h
#  fdbUlShLAe6KnRE7
#  ZwAZf2ybBcfNn3kg
#  77eHgsawe7CYCIS5
#  ouG7N3gQkRWeJrDx
#  p4qfxUZ4SmsLGNoc
#  9XcqKmiZPIKoKGAg
#  pIUry2WoUqppmvt3
#  SiycNIwI32yd9nUo
#  JZCqfpoUxRT8lMzi
#  hySCddglaKDk2ejN
#  QUJmjzTQosCiBm5H
# ...
