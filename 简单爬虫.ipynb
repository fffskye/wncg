# %%
import requests

if __name__ == '__main__':
    target = 'http://www.cqbz.cn/'
    req = requests.get(url=target)
    print(req.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#
#     <meta charset="UTF-8">
#     <title>重庆市第八中学官网-诚勤立达</title>
#     <script src="/static/js/jquery-3.1.0.min.js"></script>
#     <style>
#         * {
#             margin: 0;
#             padding: 0;
#         }
#         body {
#             width: 100%;
#             height: auto;
#             background: #f5f6f8 url("/static/image/new/land-bg.jpg") no-repeat top center;
#         }
#         .main {
#             width: 1200px;
#             height: auto;
#             overflow: hidden;
#             margin-left:auto;
#             margin-right: auto;
#         }
#         .banner {
#             width: 1200px;
#             height: 750px;
#             background: url("/static/image/new/land-b.jpg") no-repeat center;
#         }
#         .logo {
#             width: 339px;
#             height: 211px;
#             margin-right: auto;
#             margin-left:auto;
#             padding-top: 190px;
#         }
#
# ...
